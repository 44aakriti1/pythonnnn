# %%
print('yo hamro second class ho')
# Out:
# yo hamro second class ho

# %%
#this isn't that important

# %%
'''
multiline 
comment
o
yo
yokgf
kdofk
'''
# Out:
# '\nmultiline \ncomment\no\nyo\nyokgf\nkdofk\n'

# %%
a="aakriti"
b= 56
c= 25.32
student_x= False

# %%
a
# Out:
# 'aakriti'

# %%
b
# Out:
# 56

# %%
c
# Out:
# 25.32

# %%
student_x
# Out:
# False

# %%
type(a)
# Out:
# str

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# float

# %%
type(student_x)
# Out:
# bool

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
result= 5>9

# %% [raw]
# result

# %%
a="5"
b="4"
c=a+b

# %%
c
# Out:
# '54'

# %%
d= int(a)+int(b)

# %%
d
# Out:
# 9

# %%
Name= input("Enter the name")
# Out:
# Enter the name 55

# %%
type(Name)
# Out:
# str

# %%
age = int (input("enter the age"))
# Out:
# enter the age 45

# %%
type(age)
# Out:
# int

# %%
age= input("enter the age")
# Out:
# enter the age 55

# %%
type(age)
# Out:
# str

# %%
int(age)
# Out:
# 55

# %%
type(age)
# Out:
# str

# %%
x = int("5")
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
y = str(10.5)
print(y)
print(type(y))
# Out:
# 10.5
# <class 'str'>

# %%
z = float(6)
print(z)
print(type(z))
# Out:
# 6.0
# <class 'float'>

# %%
x=25
y=15


print(x+y, x-y, x/y, x*y, x//y, x%y, x**y)
# Out:
# 40 10 1.6666666666666667 375 1 10 931322574615478515625

# %%
x=25
y=15


print(f"Addition{x+y}, Subtraction{x-y}, Division{x/y}, Multiplication{x*y}, Float division{x//y}, Remainder{x%y},  Power{x**y}")
# Out:
# Addition40, Subtraction10, Division1.6666666666666667, Multiplication375, Float division1, Remainder10,  Power931322574615478515625

# %%
x=5
x+=10

# %%
x
# Out:
# 15

# %%
y=10
y-=5

# %%
y
# Out:
# 5

# %%
a=10
b=15

# %%
print(a==b)
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
age = int(input("Enter the age:"))
is_adult = age >= 18

print(is_adult)
# Out:
# Enter the age: 25
# True

# %%
age = 22
has_ticket = True

can_enter = age >= 18 and has_ticket
print(can_enter)
# Out:
# True

# %%
age = int(input("Enter your age: "))
has_ticket = True

can_enter = age >= 18 and has_ticket
print(can_enter)
# Out:
# Enter your age:  15
# False

# %%
#Assignment
item1_price = int(input("Enter price of first item: "))
item2_price = int(input("Enter price of second item: "))
item3_price = int(input("Enter price of third item"))
subtotal = item1_price + item2_price + item3_price
tax = 0.08*subtotal
total = subtotal + tax
print(f"subtotal:{subtotal}, tax:{tax}, total:{total}")
# Out:
# Enter price of first item:  200
# Enter price of second item:  2000
# Enter price of third item 4656
# subtotal:6856, tax:548.48, total:7404.48

# %%
result = 10/2

# %%
result
# Out:
# 5.0

# %%
a = 10//2

# %%
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
a=10//2
type(a)
# Out:
# int

# %%
s = "PythonProgramming"
print(s[:6])
# Out:
# Python

# %%
print(s[9:13])
# Out:
# gram

# %%
print(s[::-1])
# Out:
# gnimmargorPnohtyP

# %%
x = int(input("enter a number: "))
even= (x%2 ==0)
print(even)
# Out:
# enter a number:  40
# True

# %%
guests = ["Alice", "Bob", "Charlie", "David"]
guests.remove("Bob")
guests.insert(0, "Eve")
guests.append("Frank")
print("Final list:", guests)
print("total number of guests:" ,len(guests))
# Out:
# Final list: ['Eve', 'Alice', 'Charlie', 'David', 'Frank']
# total number of guests: 5

# %%
email_input = " UseR@ExAMPle.CoM "
email_input.strip()
email_input.lower()
email_input.replace("com" , "org")
# Out:
# ' UseR@ExAMPle.CoM '

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
print(2 ** 3 ** 0)
# Out:
# 2
