# %%
is_student = True
has_id = True
in_dress = False

# %%
if is_student and has_id and in_dress:
    print("Entry Allowed")

elif is_student and in_dress or has_id:
    print("Partially Entry Allowed")
    if is_student and has_id:
        print("Not allowed in classroom")

else:
    print("Not Allowed in Classroom")
# Out:
# Partially Entry Allowed
# Not allowed in classroom

# %%
a = ["Example" , "one" , 3]
if "Example" in a

# %%
a = [1, 2, 3]
b = a          
c = [1, 2, 3]  

print(a is b)      
print(a is not b)  

print(a is c)      
print(a is not c)
# Out:
# True
# False
# False
# True

# %%
email_input = " UseR@ExAMPle.CoM "
email_output = email_input.strip().lower().replace("com" , "org")
print(email_output)
# Out:
# user@example.org

# %%
coords=(10,20)
coords = (15,coords[1])
print(coords)
# Out:
# (15, 20)

# %%
ids = [101, 102, 101, 103, 104, 102]
unique_ids = set(ids)
count = len(unique_ids)
print(unique_ids)
print(f"Count of unique ids: {count}")
# Out:
# {104, 101, 102, 103}
# Count of unique ids: 4

# %%
date_string = "2023-12-25"
year = date_string[:4]
month = date_string[5:7]
date = date_string[8:10]
print(f"{month}/{date}/{year}")
# Out:
# 12/25/2023

# %%
file_name = " My Summer Vacation PHOTO.JPG "
standard_name = file_name.strip().lower().replace(" " , "_")
print(standard_name)
# Out:
# my_summer_vacation_photo.jpg
